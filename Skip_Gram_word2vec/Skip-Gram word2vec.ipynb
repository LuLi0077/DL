# %% [markdown]
# # Skip-gram word2vec

# %%
import time
import numpy as np
import tensorflow as tf
import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:16, 1.86MB/s]

# %% [markdown]
# ## Preprocessing
#
# The `preprocess` function coverts any punctuation into tokens, so a period is changed to `<PERIOD>`. In this data set, there aren't any periods, but it will help in other NLP problems. We also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.

# %%
from collections import Counter
import random

t = 1e-5
count = Counter(int_words)
f = {word: ct/len(int_words) for word, ct in count.items()}
p = {word: 1 - np.sqrt(t/f[word]) for word in f}
train_words = [word for word in int_words if p[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding
#
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6635 0.3065 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6290 0.3009 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5351 0.3134 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5714 0.3043 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5354 0.3038 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5432 0.3190 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5551 0.3014 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5601 0.2995 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4593 0.3025 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4694 0.3104 sec/batch
# Nearest to i: salad, brenda, repainted, nlcs, import, tima, risk, tetragrammaton,
# Nearest to zero: forensics, stele, elamites, stwa, estimation, sacerdotal, sectioning, chlorination,
# Nearest to five: human, mpv, youngest, vauxhall, lowercase, hydrazine, google, sixxs,
# Nearest to can: ks, nuns, cerca, niz, strangled, andamanese, sabina, sorbs,
# Nearest to been: minter, photonic, lifetime, chondrite, collating, priests, yelled, neoliberalism,
# Nearest to to: hospitality, tallulah, founded, gartner, people, cfl, halving, phipps,
# Nearest to however: destroying, hubris, under, fork, eurocheque, nurse, denton, granger,
# Nearest to into: mannerisms, accademia, insightful, tons, protruding, sphere, googol, centres,
# Nearest to test: unbundling, creatively, petrie, aph, parenthesized, ballpoint, presaging, pfc,
# Nearest to experience: barra, lesion, leland, quijote, maturing, lund, runtime, sncf,
# Nearest to proposed: aides, hou, lightfoot, pseudolus, dagobert, splitter, ulm, mandy,
# Nearest to creation: nick, roderick, amalthea, yaoi, congruence, feminine, scifan, sceptre,
# Nearest to bbc: serco, bronislaw, sealand, branden, personaggi, preferred, dpi, bech,
# Nearest to shows: coffey, grumman, tomography, ebooks, beeswax, willingness, excavating, judaica,
# Nearest to pope: skenderbeg, polysaccharide, mornington, policy, racks, topple, flipping, whey,
# Nearest to issue: sgi, aquarius, sidespin, camulodunum, pilots, ledyard, sk, among,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4850 0.3086 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4102 0.2839 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3380 0.2770 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2706 0.2757 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1966 0.2692 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1603 0.2998 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1068 0.3140 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0769 0.3131 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0046 0.3142 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9859 0.3122 sec/batch
# Nearest to i: salad, import, risk, repainted, causes, defeated, nlcs, pure,
# Nearest to zero: forensics, elamites, stele, main, estimation, discussing, wesleyan, tumor,
# Nearest to five: human, youngest, lowercase, moving, britannia, mpv, vauxhall, invoked,
# Nearest to can: methods, concept, ks, sabina, nuns, rely, ethnic, funding,
# Nearest to been: photonic, lifetime, minter, priests, asexual, shenanigans, collating, ganglia,
# Nearest to to: people, founded, relatively, hospitality, gartner, changes, tallulah, interrelated,
# Nearest to however: destroying, under, going, fork, revelation, diophantine, police, hubris,
# Nearest to into: mannerisms, required, tons, sphere, accademia, for, centres, action,
# Nearest to test: creatively, unbundling, parenthesized, ballpoint, banknotes, complicated, becket, striped,
# Nearest to experience: subject, second, but, sensors, lisp, ongoing, lund, lesion,
# Nearest to proposed: falkirk, original, laboratory, commission, cab, dagobert, efforts, lightfoot,
# Nearest to creation: nick, congruence, technology, organization, said, feminine, lord, roderick,
# Nearest to bbc: serco, understanding, bronislaw, preferred, branden, authored, sealand, sticking,
# Nearest to shows: coffey, tomography, grumman, ebooks, judaica, europa, willingness, licence,
# Nearest to pope: skenderbeg, policy, topple, flipping, polysaccharide, mornington, rely, moderating,
# Nearest to issue: among, online, du, sgi, camulodunum, sk, rail, crag,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9524 0.3163 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9094 0.3172 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8972 0.3156 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8328 0.3142 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8177 0.3098 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8141 0.3127 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7935 0.3112 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8009 0.3116 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7745 0.3122 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7812 0.3129 sec/batch
# Nearest to i: salad, brenda, import, pure, repainted, risk, aspect, nlcs,
# Nearest to zero: forensics, garfield, elamites, kiev, dissenting, insecure, eagle, estimation,
# Nearest to five: vauxhall, britannia, youngest, lowercase, assert, pictured, gujarat, benjamin,
# Nearest to can: methods, ks, sabina, appropriate, portability, rely, nuns, strangled,
# Nearest to been: photonic, lifetime, minter, asexual, priests, shenanigans, collating, angry,
# Nearest to to: people, hospitality, founded, interrelated, noticeably, gartner, relatively, both,
# Nearest to however: destroying, under, going, hubris, revelation, fork, nurse, exercising,
# Nearest to into: tons, accademia, mannerisms, required, googol, sphere, for, insightful,
# Nearest to test: creatively, becket, unbundling, ballpoint, parenthesized, striped, jointly, margins,
# Nearest to experience: sensors, lisp, subject, second, ongoing, lund, but, sncf,
# Nearest to proposed: nazi, falkirk, vagus, laboratory, hou, commission, cab, affirmed,
# Nearest to creation: nick, congruence, feminine, organization, amalthea, technology, roderick, matthew,
# Nearest to bbc: understanding, preferred, serco, bronislaw, gamma, ring, authored, fortune,
# Nearest to shows: coffey, willingness, ebooks, tomography, grumman, europa, judaica, oscillation,
# Nearest to pope: skenderbeg, policy, topple, manuscript, prelude, flipping, moderating, sneak,
# Nearest to issue: pilots, sgi, among, online, les, du, camulodunum, vocals,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7677 0.3163 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7582 0.3129 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7039 0.3138 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7156 0.3047 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7376 0.3081 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7070 0.3148 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6979 0.3206 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7263 0.3160 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7057 0.3198 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6789 0.3059 sec/batch
# Nearest to i: salad, brenda, import, repainted, tima, nlcs, pure, aspect,
# Nearest to zero: forensics, garfield, elamites, births, eagle, kiev, colonialists, one,
# Nearest to five: eight, vauxhall, benjamin, britannia, gujarat, population, pictured, youngest,
# Nearest to can: portability, appropriate, methods, ks, sabina, rely, viscosity, load,
# Nearest to been: photonic, lifetime, minter, asexual, priests, collating, assembly, xanadu,
# Nearest to to: people, hospitality, gartner, noticeably, interrelated, founded, both, imprisonment,
# Nearest to however: destroying, under, going, hubris, iata, greedy, transcend, nurse,
# Nearest to into: insightful, mannerisms, accademia, protruding, tons, required, confiscation, concretely,
# Nearest to test: creatively, unbundling, becket, parenthesized, margins, ballpoint, striped, assassins,
# Nearest to experience: lisp, lund, sensors, seconda, ongoing, lesion, runtime, but,
# Nearest to proposed: lightfoot, hou, affirmed, nazi, vagus, dagobert, cab, laboratory,
# Nearest to creation: nick, congruence, roderick, feminine, organization, amalthea, scifan, dogsled,
# Nearest to bbc: bronislaw, preferred, understanding, fortune, serco, sticking, trend, bulbs,
# Nearest to shows: coffey, ebooks, willingness, grumman, excavating, tomography, europa, beeswax,
# Nearest to pope: skenderbeg, topple, policy, battalion, manuscript, elbow, sneak, corolla,
# Nearest to issue: sgi, pilots, among, crag, overlaps, vocals, tallulah, fairest,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6887 0.3160 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6615 0.3146 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6179 0.3192 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6308 0.3181 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6087 0.3145 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6168 0.3297 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5829 0.2264 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5495 0.3112 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5183 0.3163 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5099 0.3159 sec/batch
# Nearest to i: salad, brenda, repainted, aspect, nlcs, import, tima, margrave,
# Nearest to zero: forensics, garfield, one, births, kiev, elamites, galil, eagle,
# Nearest to five: eight, vauxhall, benjamin, britannia, st, gujarat, b, patricia,
# Nearest to can: methods, appropriate, portability, defined, sabina, ks, rely, viscosity,
# Nearest to been: photonic, minter, lifetime, asexual, collating, priests, assembly, mallet,
# Nearest to to: people, noticeably, hospitality, gartner, both, imprisonment, interrelated, carefully,
# Nearest to however: destroying, under, going, greedy, transcend, iata, hubris, bilateral,
# Nearest to into: insightful, mannerisms, protruding, accademia, required, ductile, concretely, confiscation,
# Nearest to test: unbundling, creatively, ballpoint, petrie, becket, margins, parenthesized, striped,
# Nearest to experience: lisp, seconda, sensors, but, ongoing, escapades, lund, raves,
# Nearest to proposed: hou, lightfoot, laboratory, vagus, affirmed, commission, dagobert, aides,
# Nearest to creation: congruence, nick, roderick, organization, feminine, amalthea, scifan, sceptre,
# Nearest to bbc: bronislaw, fortune, serco, bulbs, sunset, decorated, preferred, branden,
# Nearest to shows: coffey, willingness, ebooks, grumman, excavating, judaica, tomography, europa,
# Nearest to pope: skenderbeg, topple, battalion, policy, manuscript, cricketer, elbow, corolla,
# Nearest to issue: sgi, pilots, among, retraction, crag, propose, tallulah, fairest,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4891 0.3178 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5064 0.3145 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4475 0.3145 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5320 0.3111 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4956 0.3263 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4778 0.3304 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4538 0.3202 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4078 0.3197 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4528 0.3151 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4225 0.3131 sec/batch
# Nearest to i: salad, tima, aspect, margrave, import, kodokan, nlcs, brenda,
# Nearest to zero: one, two, births, four, elamites, garfield, nasl, main,
# Nearest to five: eight, vauxhall, reserves, benjamin, population, britannia, patricia, xv,
# Nearest to can: portability, methods, defined, appropriate, sabina, viscosity, ks, rely,
# Nearest to been: photonic, minter, lifetime, collating, chondrite, asexual, priests, yelled,
# Nearest to to: people, hospitality, gartner, both, noticeably, eschew, interrelated, carefully,
# Nearest to however: destroying, under, going, greedy, iata, transcend, philos, hubris,
# Nearest to into: insightful, mannerisms, accademia, phenomenally, ductile, protruding, concretely, required,
# Nearest to test: unbundling, creatively, ballpoint, becket, presaging, striped, petrie, parenthesized,
# Nearest to experience: lisp, seconda, but, downsized, arguments, sensors, raves, escapades,
# Nearest to proposed: hou, lightfoot, laboratory, vagus, affirmed, splitter, dagobert, aides,
# Nearest to creation: congruence, amalthea, roderick, feminine, organization, antiarrhythmic, sceptre, nick,
# Nearest to bbc: bronislaw, decorated, serco, fortune, dpi, bulbs, trend, medina,
# Nearest to shows: coffey, grumman, ebooks, willingness, excavating, tomography, judaica, europa,
# Nearest to pope: skenderbeg, battalion, topple, manuscript, policy, cricketer, corolla, succeeded,
# Nearest to issue: sgi, pilots, among, retraction, propose, fairest, tallulah, recognition,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4470 0.3239 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4204 0.3243 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4207 0.3276 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3765 0.3252 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3992 0.3117 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4452 0.3129 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3854 0.3176 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3940 0.2984 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4167 0.2724 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3586 0.3090 sec/batch
# Nearest to i: salad, tima, margrave, kodokan, import, aspect, you, nlcs,
# Nearest to zero: two, one, four, births, rochester, garfield, nasl, runways,
# Nearest to five: eight, vauxhall, benjamin, one, reserves, six, patricia, xv,
# Nearest to can: portability, methods, defined, appropriate, ks, load, scalable, carbine,
# Nearest to been: photonic, lifetime, minter, collating, mallet, asexual, shenanigans, chondrite,
# Nearest to to: people, imprisonment, gartner, hospitality, carefully, both, changes, interrelated,
# Nearest to however: under, destroying, going, philos, greedy, iata, voters, revelation,
# Nearest to into: insightful, mannerisms, concretely, phenomenally, protruding, accademia, required, ductile,
# Nearest to test: unbundling, creatively, ballpoint, striped, complicated, presaging, proctor, petrie,
# Nearest to experience: seconda, but, lisp, arguments, sensors, lesion, raves, dictatorships,
# Nearest to proposed: hou, lightfoot, commission, laboratory, affirmed, splitter, vagus, aides,
# Nearest to creation: congruence, amalthea, roderick, feminine, organization, apply, foundations, yaoi,
# Nearest to bbc: decorated, serco, bronislaw, fortune, dpi, bulbs, trend, branden,
# Nearest to shows: coffey, excavating, ebooks, europa, beeswax, tomography, willingness, grumman,
# Nearest to pope: skenderbeg, battalion, topple, orthodox, manuscript, cricketer, corolla, policy,
# Nearest to issue: sgi, pilots, propose, retraction, congeniality, among, recognition, tallulah,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3628 0.3082 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3799 0.3011 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3546 0.3017 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3666 0.3008 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4081 0.2994 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3638 0.3006 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3777 0.3001 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3896 0.2996 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3352 0.3004 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3193 0.2993 sec/batch
# Nearest to i: salad, margrave, tima, you, arjuna, nlcs, brenda, repainted,
# Nearest to zero: two, one, three, four, six, rochester, est, runways,
# Nearest to five: eight, vauxhall, one, six, three, reserves, population, zero,
# Nearest to can: portability, appropriate, ks, defined, scalable, load, methods, carbine,
# Nearest to been: photonic, minter, lifetime, collating, mallet, asexual, sentiment, priests,
# Nearest to to: people, imprisonment, agree, changes, gartner, carefully, an, hospitality,
# Nearest to however: destroying, under, going, political, bilateral, greedy, voters, kepler,
# Nearest to into: insightful, mannerisms, concretely, required, phenomenally, payton, sphere, googol,
# Nearest to test: creatively, unbundling, ballpoint, striped, meddle, presaging, hayastan, gimpshop,
# Nearest to experience: seconda, arguments, but, lesion, sensors, raves, lisp, runtime,
# Nearest to proposed: lightfoot, hou, commission, affirmed, dagobert, laboratory, efforts, splitter,
# Nearest to creation: amalthea, congruence, roderick, yaoi, feminine, foundations, apply, organization,
# Nearest to bbc: decorated, serco, fortune, bronislaw, dpi, bulbs, trend, kate,
# Nearest to shows: coffey, europa, excavating, ebooks, oft, beeswax, grumman, willingness,
# Nearest to pope: skenderbeg, orthodox, battalion, topple, policy, corolla, manuscript, mornington,
# Nearest to issue: sgi, propose, pilots, recognition, among, retraction, crag, congeniality,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3487 0.3052 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2564 0.3036 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3952 0.3026 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3783 0.3009 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4114 0.2995 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2929 0.3002 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3076 0.2994 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3380 0.2993 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2400 0.2991 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2976 0.3004 sec/batch
# Nearest to i: salad, you, margrave, tima, sings, says, my, arjuna,
# Nearest to zero: two, one, three, four, births, six, est, five,
# Nearest to five: eight, one, six, zero, three, vauxhall, population, benjamin,
# Nearest to can: portability, appropriate, scalable, defined, ks, keyword, cerca, carbine,
# Nearest to been: photonic, minter, mallet, lifetime, chondrite, shenanigans, sentiment, massing,
# Nearest to to: people, gartner, changes, abate, hospitality, imprisonment, an, agree,
# Nearest to however: going, destroying, under, voters, eurocheque, kepler, bilateral, hizballah,
# Nearest to into: insightful, mannerisms, czi, confiscation, concretely, phenomenally, breaks, stupor,
# Nearest to test: unbundling, ballpoint, creatively, striped, invert, presaging, sherry, meddle,
# Nearest to experience: arguments, lesion, but, seconda, raves, escapades, ongoing, sensors,
# Nearest to proposed: lightfoot, hou, commission, affirmed, dagobert, nazi, efforts, thwarted,
# Nearest to creation: amalthea, roderick, yaoi, feminine, congruence, antiarrhythmic, apply, foundations,
# Nearest to bbc: decorated, listing, serco, bronislaw, fortune, trend, dpi, jersey,
# Nearest to shows: coffey, europa, ebooks, excavating, oft, beeswax, grumman, judaica,
# Nearest to pope: skenderbeg, battalion, topple, orthodox, corolla, clergyman, manuscript, policy,
# Nearest to issue: sgi, propose, recognition, crag, pilots, tallulah, among, congeniality,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2970 0.2866 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2713 0.2647 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3582 0.1103 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2610 0.2591 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2252 0.2582 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2069 0.2584 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2072 0.2592 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2134 0.2994 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2198 0.3018 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2087 0.3020 sec/batch
# Nearest to i: salad, margrave, you, my, says, tima, marry, sings,
# Nearest to zero: two, one, four, three, five, est, six, births,
# Nearest to five: eight, one, six, vauxhall, zero, three, population, median,
# Nearest to can: portability, outweighed, cerca, ks, scalable, defined, load, appropriate,
# Nearest to been: photonic, minter, lifetime, sentiment, chondrite, staking, mallet, massing,
# Nearest to to: abate, people, managed, hospitality, gartner, heracles, changes, met,
# Nearest to however: going, destroying, under, voters, puck, hizballah, exercising, eurocheque,
# Nearest to into: insightful, mannerisms, payton, stupor, czi, ashburton, confiscation, breaks,
# Nearest to test: unbundling, ballpoint, creatively, presaging, striped, invert, proctor, sherry,
# Nearest to experience: lesion, arguments, but, seconda, escapades, ongoing, raves, abusers,
# Nearest to proposed: hou, commission, lightfoot, affirmed, dagobert, nazi, thwarted, efforts,
# Nearest to creation: amalthea, roderick, yaoi, congruence, foundations, feminine, antiarrhythmic, apply,
# Nearest to bbc: decorated, listing, trend, dpi, bronislaw, serco, fortune, ee,
# Nearest to shows: coffey, ebooks, europa, oft, excavating, grumman, beeswax, judaica,
# Nearest to pope: skenderbeg, battalion, apostolic, clergyman, topple, orthodox, policy, corolla,
# Nearest to issue: sgi, propose, recognition, crag, pilots, congeniality, circe, retraction,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2228 0.3028 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2288 0.2994 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2548 0.2980 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1277 0.2995 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1527 0.2991 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2040 0.2979 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1789 0.2979 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1807 0.2991 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2129 0.2991 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1850 0.2992 sec/batch
# Nearest to i: you, salad, margrave, sends, tima, my, nahum, says,
# Nearest to zero: two, one, three, four, five, births, est, six,
# Nearest to five: eight, one, six, zero, three, vauxhall, median, population,
# Nearest to can: portability, outweighed, appropriate, defined, scalable, keyword, glutamate, secretions,
# Nearest to been: photonic, lifetime, mallet, chondrite, minter, massing, shenanigans, sentiment,
# Nearest to to: abate, agree, must, gartner, changes, people, facilitation, imprisonment,
# Nearest to however: going, destroying, under, puck, eurocheque, voters, kepler, curium,
# Nearest to into: insightful, mannerisms, czi, breaks, googol, duct, confiscation, ashburton,
# Nearest to test: unbundling, ballpoint, creatively, august, presaging, invert, striped, sherry,
# Nearest to experience: lesion, arguments, seconda, escapades, raves, ongoing, but, others,
# Nearest to proposed: hou, commission, affirmed, lightfoot, thwarted, splitter, efforts, dagobert,
# Nearest to creation: amalthea, congruence, yaoi, roderick, foundations, feminine, rationalist, apply,
# Nearest to bbc: decorated, listing, trend, dpi, serco, ee, fortune, bronislaw,
# Nearest to shows: coffey, ebooks, oft, europa, excavating, tomography, beeswax, grumman,
# Nearest to pope: skenderbeg, apostolic, orthodox, christology, chalcedon, mornington, topple, papal,
# Nearest to issue: sgi, propose, recognition, crag, congeniality, retraction, pilots, circe,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2067 0.3054 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2237 0.3093 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1608 0.3098 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1622 0.3054 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1869 0.3144 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1923 0.2998 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1888 0.2993 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1554 0.3024 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1081 0.3034 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1871 0.2657 sec/batch
# Nearest to i: you, my, sends, salad, margrave, sings, says, nahum,
# Nearest to zero: two, one, three, four, five, six, est, rate,
# Nearest to five: eight, one, six, three, zero, vauxhall, median, million,
# Nearest to can: portability, outweighed, defined, appropriate, cerca, secretions, glutamate, scalable,
# Nearest to been: photonic, lifetime, collating, minter, sentiment, mallet, chondrite, neoliberalism,
# Nearest to to: abate, imprisonment, people, must, effected, changes, mucosa, agree,
# Nearest to however: going, destroying, under, puck, curium, enlarged, eurocheque, sprouse,
# Nearest to into: mannerisms, insightful, ashburton, breaks, czi, tolls, googol, payton,
# Nearest to test: unbundling, ballpoint, creatively, striped, august, proctor, hayastan, presaging,
# Nearest to experience: lesion, ongoing, seconda, escapades, raves, but, arguments, others,
# Nearest to proposed: hou, commission, affirmed, lightfoot, efforts, splitter, thwarted, data,
# Nearest to creation: congruence, amalthea, roderick, yaoi, foundations, feminine, rationalist, organization,
# Nearest to bbc: decorated, listing, trend, dpi, cigarettes, serco, ee, fortune,
# Nearest to shows: coffey, europa, ebooks, oft, excavating, beeswax, grumman, tomography,
# Nearest to pope: skenderbeg, chalcedon, mornington, apostolic, corolla, christology, topple, encyclical,
# Nearest to issue: sgi, propose, circe, pilots, recognition, crag, congeniality, retraction,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1987 0.2984 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1916 0.3040 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1778 0.3018 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1904 0.2983 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1403 0.2997 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1710 0.3035 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1583 0.2994 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1296 0.2789 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1716 0.2767 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2089 0.3009 sec/batch
# Nearest to i: you, my, sends, margrave, sings, salad, says, tima,
# Nearest to zero: two, one, three, four, six, five, eight, births,
# Nearest to five: eight, one, six, three, zero, four, vauxhall, years,
# Nearest to can: portability, glutamate, secretions, cerca, appropriate, outweighed, ks, defined,
# Nearest to been: photonic, lifetime, minter, sentiment, neoliberalism, collating, chondrite, mallet,
# Nearest to to: imprisonment, abate, people, heracles, managed, met, agree, dilapidated,
# Nearest to however: going, destroying, puck, under, voters, staged, sprouse, have,
# Nearest to into: insightful, shah, breaks, mannerisms, ashburton, czi, withstood, centres,
# Nearest to test: unbundling, ballpoint, creatively, striped, presaging, zildjian, hayastan, proctor,
# Nearest to experience: lesion, seconda, ongoing, escapades, raves, lisp, arguments, americanization,
# Nearest to proposed: hou, commission, lightfoot, affirmed, dagobert, efforts, thwarted, nazi,
# Nearest to creation: roderick, yaoi, amalthea, organization, technology, foundations, congruence, vang,
# Nearest to bbc: listing, decorated, trend, cigarettes, dpi, fortune, ee, trucial,
# Nearest to shows: coffey, europa, oft, ebooks, excavating, enya, drama, willingness,
# Nearest to pope: skenderbeg, chalcedon, mornington, corolla, apostolic, topple, gregorian, papal,
# Nearest to issue: sgi, propose, recognition, crag, circe, retraction, modernize, congeniality,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2366 0.2990 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1394 0.2968 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1349 0.2961 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1419 0.2975 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0147 0.3052 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1261 0.3207 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1570 0.3224 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1258 0.2892 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1556 0.0382 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1304 0.2895 sec/batch
# Nearest to i: you, my, sends, sings, salad, margrave, says, puzzled,
# Nearest to zero: two, one, three, four, five, six, eight, est,
# Nearest to five: eight, one, six, three, zero, vauxhall, four, million,
# Nearest to can: portability, ks, glutamate, secretions, defined, outweighed, cerca, appropriate,
# Nearest to been: photonic, minter, lifetime, sentiment, staking, collating, mallet, neoliberalism,
# Nearest to to: people, abate, must, gartner, changes, mucosa, facilitation, imprisonment,
# Nearest to however: going, puck, destroying, curium, staged, unload, grammys, under,
# Nearest to into: insightful, ashburton, breaks, withstood, shah, stupor, duct, mannerisms,
# Nearest to test: unbundling, ballpoint, creatively, dumping, presaging, august, striped, zildjian,
# Nearest to experience: lesion, seconda, escapades, ongoing, lisp, raves, others, abusers,
# Nearest to proposed: hou, commission, affirmed, lightfoot, dagobert, thwarted, ulm, data,
# Nearest to creation: roderick, yaoi, technology, amalthea, organization, antiarrhythmic, foundations, scifan,
# Nearest to bbc: listing, decorated, trend, cigarettes, dpi, browser, ee, trucial,
# Nearest to shows: coffey, europa, oft, ebooks, excavating, drama, enya, vegan,
# Nearest to pope: skenderbeg, chalcedon, mornington, topple, corolla, gregorian, papal, apostolic,
# Nearest to issue: propose, sgi, circe, crag, recognition, retraction, pilots, modernize,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0826 0.3288 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0752 0.3193 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0872 0.3214 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0779 0.2842 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0659 0.2906 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0532 0.3025 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1039 0.3007 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0965 0.2555 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1085 0.2647 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0660 0.2668 sec/batch
# Nearest to i: you, my, sends, salad, margrave, says, sings, tima,
# Nearest to zero: two, one, three, four, five, six, eight, prevalence,
# Nearest to five: eight, one, six, three, zero, four, vauxhall, million,
# Nearest to can: portability, glutamate, load, ks, outweighed, secretions, cerca, scalable,
# Nearest to been: photonic, mallet, lifetime, staking, sentiment, minter, known, burroughs,
# Nearest to to: people, heracles, abate, effected, must, mucosa, proportionality, after,
# Nearest to however: going, puck, destroying, curium, under, speeds, grammys, unload,
# Nearest to into: insightful, withstood, shah, ashburton, breaks, googol, payton, townsend,
# Nearest to test: unbundling, ballpoint, dumping, creatively, presaging, zildjian, proctor, august,
# Nearest to experience: lesion, seconda, ongoing, escapades, lisp, abusers, raves, arguments,
# Nearest to proposed: hou, commission, affirmed, dagobert, lightfoot, data, thwarted, ulm,
# Nearest to creation: roderick, yaoi, technology, organization, foundations, antiarrhythmic, rationalist, amalthea,
# Nearest to bbc: listing, trend, decorated, dpi, cigarettes, browser, trucial, ee,
# Nearest to shows: coffey, europa, oft, excavating, ebooks, drama, willingness, innes,
# Nearest to pope: skenderbeg, chalcedon, gregorian, mornington, papal, corolla, topple, amuro,
# Nearest to issue: propose, sgi, modernize, crag, pilots, recognition, retraction, fairest,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0418 0.2849 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9995 0.2823 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0207 0.2954 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0571 0.2808 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0456 0.2980 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0583 0.2869 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0536 0.2574 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1170 0.2579 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0531 0.2586 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0365 0.2543 sec/batch
# Nearest to i: you, sends, my, margrave, says, salad, sings, nahum,
# Nearest to zero: two, one, three, four, five, six, prevalence, years,
# Nearest to five: eight, one, six, three, zero, four, years, vauxhall,
# Nearest to can: portability, glutamate, keyword, ks, outweighed, secretions, hopf, defined,
# Nearest to been: photonic, lifetime, sentiment, staking, mallet, burroughs, known, amply,
# Nearest to to: must, mucosa, people, abate, proportionality, effected, be, facilitation,
# Nearest to however: going, puck, have, curium, grammys, enlarged, ebony, unload,
# Nearest to into: insightful, breaks, duct, googol, characteristically, townsend, attaching, ides,
# Nearest to test: unbundling, ballpoint, dumping, wetlands, zildjian, august, presaging, gimpshop,
# Nearest to experience: seconda, lesion, ongoing, lisp, escapades, raves, others, but,
# Nearest to proposed: hou, commission, affirmed, lightfoot, data, laboratory, dagobert, thwarted,
# Nearest to creation: yaoi, roderick, technology, organization, foundations, rationalist, antiarrhythmic, amalthea,
# Nearest to bbc: listing, decorated, trend, cigarettes, dpi, trucial, browser, serco,
# Nearest to shows: coffey, europa, oft, excavating, ebooks, tomography, beeswax, drama,
# Nearest to pope: skenderbeg, mornington, chalcedon, papal, gregorian, corolla, topple, encyclical,
# Nearest to issue: sgi, propose, pilots, modernize, recognition, autograph, circe, les,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0637 0.2572 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1073 0.2551 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0398 0.2671 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0798 0.2956 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0539 0.2865 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0304 0.2533 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0714 0.2778 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0629 0.2976 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1232 0.2798 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0594 0.2555 sec/batch
# Nearest to i: my, you, sends, margrave, sings, salad, says, brenda,
# Nearest to zero: two, one, three, four, five, six, eight, prevalence,
# Nearest to five: eight, six, three, one, zero, four, vauxhall, million,
# Nearest to can: portability, load, outweighed, glutamate, cerca, hopf, signatures, appropriate,
# Nearest to been: photonic, lifetime, sentiment, known, amply, clear, staking, asexual,
# Nearest to to: people, abate, heracles, effected, mucosa, facilitation, must, proportionality,
# Nearest to however: going, have, puck, under, staged, enlarged, grammys, ebony,
# Nearest to into: insightful, shah, wresting, romanisation, ashburton, townsend, duct, decameron,
# Nearest to test: unbundling, ballpoint, dumping, wetlands, zildjian, creatively, gimpshop, proctor,
# Nearest to experience: seconda, lesion, ongoing, lisp, raves, escapades, transits, riveted,
# Nearest to proposed: hou, affirmed, commission, lightfoot, dagobert, thwarted, ulm, data,
# Nearest to creation: roderick, technology, organization, yaoi, foundations, antiarrhythmic, amalthea, vang,
# Nearest to bbc: listing, decorated, trend, cigarettes, dpi, trucial, browser, serco,
# Nearest to shows: coffey, europa, oft, willingness, ebooks, tomography, drama, blackness,
# Nearest to pope: skenderbeg, chalcedon, mornington, papal, gregorian, encyclical, topple, corolla,
# Nearest to issue: sgi, propose, pilots, modernize, recognition, autograph, les, retraction,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0711 0.2590 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0242 0.2613 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0423 0.2536 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0767 0.2623 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0334 0.2957 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1498 0.2980 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1465 0.2962 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0414 0.2974 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0224 0.2960 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0468 0.2966 sec/batch
# Nearest to i: my, you, sends, sings, says, salad, me, margrave,
# Nearest to zero: two, one, three, four, five, six, eight, prevalence,
# Nearest to five: eight, six, one, three, zero, four, years, vauxhall,
# Nearest to can: portability, glutamate, load, cerca, signatures, secretions, ks, appropriate,
# Nearest to been: photonic, lifetime, sentiment, neoliberalism, clear, staking, known, minter,
# Nearest to to: abate, people, must, facilitation, mucosa, dilapidated, proportionality, managed,
# Nearest to however: going, have, puck, staged, grammys, unload, voters, curium,
# Nearest to into: insightful, attaching, duct, romanisation, withstood, ashburton, shah, googol,
# Nearest to test: unbundling, dumping, ballpoint, gimpshop, zildjian, creatively, wetlands, proctor,
# Nearest to experience: seconda, lesion, lisp, ongoing, escapades, raves, transits, gotham,
# Nearest to proposed: hou, commission, affirmed, lightfoot, dagobert, ulm, thwarted, efforts,
# Nearest to creation: yaoi, technology, roderick, organization, foundations, antiarrhythmic, vang, scifan,
# Nearest to bbc: listing, decorated, trend, trucial, cigarettes, dpi, ee, understanding,
# Nearest to shows: coffey, europa, oft, drama, willingness, enya, ebooks, innes,
# Nearest to pope: skenderbeg, chalcedon, mornington, papal, gregorian, corolla, topple, papacy,
# Nearest to issue: propose, sgi, pilots, modernize, crag, recognition, les, autograph,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9871 0.2974 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9767 0.2949 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0510 0.2999 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0037 0.2968 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0760 0.2962 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0423 0.2498 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0055 0.2970 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9823 0.2961 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0511 0.2982 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9625 0.2949 sec/batch
# Nearest to i: my, you, sends, sings, margrave, salad, says, go,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# Nearest to five: eight, one, six, three, zero, four, two, nine,
# Nearest to can: portability, load, glutamate, signatures, outweighed, cerca, ks, secretions,
# Nearest to been: photonic, lifetime, staking, known, clear, asexual, mallet, amply,
# Nearest to to: abate, people, heracles, facilitation, met, proportionality, in, effected,
# Nearest to however: going, puck, have, unload, grammys, curium, speeds, ebony,
# Nearest to into: insightful, ashburton, shah, attaching, wresting, withstood, romanisation, duct,
# Nearest to test: unbundling, dumping, ballpoint, gimpshop, zildjian, presaging, wetlands, creatively,
# Nearest to experience: seconda, lesion, lisp, ongoing, escapades, raves, dosed, riveted,
# Nearest to proposed: hou, affirmed, dagobert, commission, lightfoot, ulm, thwarted, duomo,
# Nearest to creation: yaoi, roderick, technology, foundations, antiarrhythmic, organization, vang, monopolization,
# Nearest to bbc: listing, decorated, trend, trucial, cigarettes, dpi, ora, octavia,
# Nearest to shows: coffey, europa, oft, willingness, blackness, drama, ebooks, innes,
# Nearest to pope: skenderbeg, mornington, chalcedon, gregorian, corolla, papal, pius, papacy,
# Nearest to issue: sgi, propose, pilots, recognition, modernize, autograph, crag, kirby,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9894 0.2991 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9408 0.2977 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9982 0.2972 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0261 0.2960 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9979 0.2969 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9675 0.2954 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8877 0.2947 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9708 0.2957 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9636 0.2957 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9463 0.2992 sec/batch
# Nearest to i: my, you, sends, salad, sings, says, margrave, me,
# Nearest to zero: two, one, three, four, five, six, eight, years,
# Nearest to five: six, eight, one, three, zero, four, two, years,
# Nearest to can: portability, load, glutamate, signatures, outweighed, cerca, ks, hopf,
# Nearest to been: photonic, staking, lifetime, amply, mallet, known, clear, sentiment,
# Nearest to to: people, abate, heracles, facilitation, must, from, in, mucosa,
# Nearest to however: going, have, puck, unload, grammys, destroying, speeds, ebony,
# Nearest to into: insightful, ashburton, duct, shah, romanisation, wresting, townsend, attaching,
# Nearest to test: unbundling, dumping, ballpoint, gimpshop, wetlands, zildjian, presaging, august,
# Nearest to experience: seconda, lesion, lisp, escapades, ongoing, raves, riveted, dosed,
# Nearest to proposed: hou, affirmed, dagobert, commission, lightfoot, lcm, ulm, vagus,
# Nearest to creation: yaoi, roderick, antiarrhythmic, organization, foundations, technology, rationalist, vang,
# Nearest to bbc: listing, decorated, trucial, trend, cigarettes, november, hynek, broadcasting,
# Nearest to shows: coffey, europa, oft, blackness, tomography, willingness, drama, ebooks,
# Nearest to pope: skenderbeg, chalcedon, mornington, papal, gregorian, corolla, papacy, pius,
# Nearest to issue: sgi, propose, pilots, recognition, modernize, autograph, les, brokerage,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0116 0.2717 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0241 0.2721 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9617 0.2640 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9989 0.2575 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0462 0.2587 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9453 0.2584 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9880 0.2746 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0072 0.2984 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9938 0.2956 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9705 0.2960 sec/batch
# Nearest to i: my, you, sends, sings, me, go, t, salad,
# Nearest to zero: two, one, three, four, five, six, eight, years,
# Nearest to five: eight, one, six, three, four, zero, nine, two,
# Nearest to can: portability, load, signatures, glutamate, hopf, cerca, defined, step,
# Nearest to been: lifetime, photonic, known, amply, clear, have, neoliberalism, burroughs,
# Nearest to to: abate, people, in, from, be, proportionality, heracles, agree,
# Nearest to however: going, have, puck, unload, grammys, booting, curium, voters,
# Nearest to into: insightful, duct, eukaryotes, breaks, townsend, romanisation, attaching, characteristically,
# Nearest to test: unbundling, ballpoint, dumping, gimpshop, zildjian, creatively, accordingly, presaging,
# Nearest to experience: seconda, lisp, lesion, ongoing, escapades, raves, riveted, dosed,
# Nearest to proposed: hou, affirmed, commission, dagobert, lightfoot, efforts, thwarted, robust,
# Nearest to creation: yaoi, roderick, foundations, technology, organization, rationalist, antiarrhythmic, vang,
# Nearest to bbc: listing, november, trend, trucial, cigarettes, decorated, hynek, dpi,
# Nearest to shows: coffey, europa, drama, blackness, tomography, oft, willingness, dubbing,
# Nearest to pope: skenderbeg, mornington, chalcedon, gregorian, papal, corolla, papacy, pius,
# Nearest to issue: sgi, propose, recognition, pilots, les, kirby, modernize, autograph,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9933 0.3006 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9573 0.2967 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9727 0.2951 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9997 0.2957 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0004 0.2987 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0014 0.2978 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9816 0.2976 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9623 0.2972 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9775 0.2948 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0240 0.2978 sec/batch
# Nearest to i: my, you, sends, sings, me, t, brenda, know,
# Nearest to zero: two, three, one, four, five, six, eight, years,
# Nearest to five: eight, six, three, one, four, zero, two, million,
# Nearest to can: portability, load, signatures, cerca, glutamate, keyword, appropriate, secretions,
# Nearest to been: clear, known, lifetime, photonic, have, neoliberalism, burroughs, staking,
# Nearest to to: abate, people, in, from, be, facilitation, also, an,
# Nearest to however: have, going, puck, booting, voters, curium, under, iata,
# Nearest to into: duct, insightful, ashburton, eukaryotes, breaks, attaching, romanisation, wresting,
# Nearest to test: unbundling, dumping, ballpoint, gimpshop, creatively, wetlands, accordingly, zildjian,
# Nearest to experience: lisp, seconda, lesion, ongoing, riveted, raves, escapades, dosed,
# Nearest to proposed: hou, affirmed, dagobert, lightfoot, efforts, commission, robust, thwarted,
# Nearest to creation: yaoi, technology, roderick, vang, antiarrhythmic, organization, foundations, rationalist,
# Nearest to bbc: listing, cigarettes, trucial, november, trend, decorated, hynek, aired,
# Nearest to shows: coffey, europa, drama, blackness, oft, willingness, tomography, enya,
# Nearest to pope: skenderbeg, mornington, gregorian, chalcedon, papal, corolla, papacy, pius,
# Nearest to issue: propose, sgi, recognition, modernize, pilots, brokerage, autograph, les,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9909 0.3011 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0854 0.2970 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0311 0.2945 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0275 0.2954 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9568 0.2959 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9330 0.2963 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0130 0.2942 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9140 0.2962 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9950 0.2982 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9662 0.2960 sec/batch
# Nearest to i: my, you, sings, t, me, sends, brenda, know,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8097 0.3000 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8051 0.3029 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8418 0.3078 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8740 0.2956 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8171 0.2962 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8326 0.2954 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9088 0.2948 sec/batch
# Nearest to i: you, t, my, know, am, think, me, mish,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# Nearest to five: one, eight, three, six, four, zero, two, nine,
# Nearest to can: load, portability, which, string, bootstrapping, switch, no, of,
# Nearest to been: have, known, clear, decades, staking, as, identified, these,
# Nearest to to: in, as, on, from, and, an, with, be,
# Nearest to however: have, to, was, only, not, all, unload, supremely,
# Nearest to into: own, duct, eukaryotes, their, romanisation, breaks, igg, several,
# Nearest to test: dumping, wetlands, cricket, gimpshop, accordingly, cricketers, bradman, unbundling,
# Nearest to experience: lisp, seconda, riveted, lesion, escapades, dosed, explosively, shameless,
# Nearest to proposed: intercepts, robust, affirmed, hou, expunged, refinements, inaccuracy, dagobert,
# Nearest to creation: lord, roderick, anshan, tricyclic, yaoi, antiarrhythmic, rationalist, inconsistent,
# Nearest to bbc: listing, november, commentary, december, aired, trucial, optic, hynek,
# Nearest to shows: drama, tomography, sle, blackness, disturbances, innes, asymmetrical, visitors,
# Nearest to pope: papal, sainthood, skenderbeg, gregorian, papacy, mornington, pius, lockyer,
# Nearest to issue: kirby, sgi, heath, les, busting, lloyd, burn, congeniality,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8239 0.2988 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8484 0.2970 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8857 0.2964 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8746 0.2964 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8557 0.2953 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8675 0.2962 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8684 0.2965 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8316 0.2954 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8919 0.2949 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8850 0.2964 sec/batch
# Nearest to i: you, my, t, know, am, me, think, remember,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# Nearest to five: one, eight, three, six, four, zero, two, nine,
# Nearest to can: load, portability, sandbox, switch, rely, bootstrapping, no, outcomes,
# Nearest to been: have, known, clear, decades, as, these, identified, that,
# Nearest to to: in, and, from, of, as, be, with, also,
# Nearest to however: have, not, to, was, only, all, the, supremely,
# Nearest to into: own, duct, their, romanisation, eukaryotes, igg, several, the,
# Nearest to test: dumping, wetlands, gimpshop, cricket, ground, accordingly, cricketers, unbundling,
# Nearest to experience: lisp, seconda, riveted, transits, bosporus, profits, tokelau, favorites,
# Nearest to proposed: affirmed, intercepts, expunged, robust, hou, refinements, lightfoot, inaccuracy,
# Nearest to creation: lord, roderick, anshan, technology, damiano, rationalist, hinton, tricyclic,
# Nearest to bbc: listing, november, commentary, trucial, optic, hynek, aired, itv,
# Nearest to shows: drama, tomography, disturbances, sle, blackness, innes, enya, visitors,
# Nearest to pope: sainthood, papal, gregorian, papacy, skenderbeg, chalcedon, mornington, pius,
# Nearest to issue: kirby, sgi, heath, busting, decisions, modernize, les, propose,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8526 0.2994 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8631 0.2957 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8211 0.2952 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8269 0.2947 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8610 0.2965 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8529 0.2977 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9747 0.2970 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9153 0.2957 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9057 0.2944 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8152 0.2950 sec/batch
# Nearest to i: my, t, you, know, am, think, me, remember,
# Nearest to zero: two, one, three, four, five, six, nine, eight,
# Nearest to five: one, eight, six, three, four, zero, two, nine,
# Nearest to can: load, portability, outcomes, sandbox, glutamate, rely, switch, ethnic,
# Nearest to been: have, known, clear, as, decades, these, since, identified,
# Nearest to to: in, and, from, as, of, but, with, on,
# Nearest to however: to, have, not, only, was, a, all, the,
# Nearest to into: duct, eukaryotes, their, romanisation, own, igg, wresting, thelma,
# Nearest to test: dumping, wetlands, gimpshop, cricket, accordingly, oj, unbundling, cricketers,
# Nearest to experience: lisp, dosed, seconda, transits, tokelau, escapades, favorites, riveted,
# Nearest to proposed: intercepts, expunged, affirmed, hou, dagobert, translating, lightfoot, robust,
# Nearest to creation: lord, disbandment, roderick, damiano, technology, inconsistent, vang, foundations,
# Nearest to bbc: listing, november, commentary, december, trucial, raided, hydrated, optic,
# Nearest to shows: drama, tomography, sle, disturbances, innes, enya, blackness, europa,
# Nearest to pope: papal, sainthood, papacy, skenderbeg, gregorian, chalcedon, mornington, pius,
# Nearest to issue: kirby, heath, busting, decisions, modernize, les, ashcroft, sgi,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8146 0.2972 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8455 0.2944 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8064 0.2968 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8618 0.2957 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8489 0.2954 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8450 0.2951 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9142 0.1160 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8162 0.2952 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8375 0.2964 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8654 0.2964 sec/batch
# Nearest to i: my, you, t, go, know, am, mish, remember,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# Nearest to five: one, eight, six, three, four, zero, two, nine,
# Nearest to can: load, portability, rely, sandbox, outcomes, cond, ethnic, string,
# Nearest to been: have, known, as, found, decades, identified, staking, clear,
# Nearest to to: in, and, of, the, a, as, from, was,
# Nearest to however: to, have, not, was, only, a, supremely, all,
# Nearest to into: duct, eukaryotes, their, romanisation, own, thelma, wresting, they,
# Nearest to test: dumping, wetlands, cricket, ground, gimpshop, accordingly, bradman, unbundling,
# Nearest to experience: lisp, dosed, sees, tokelau, seconda, transits, riveted, discipline,
# Nearest to proposed: expunged, hou, intercepts, dagobert, inaccuracy, affirmed, robust, ulm,
# Nearest to creation: lord, technology, roderick, inconsistent, damiano, playable, disbandment, antiarrhythmic,
# Nearest to bbc: listing, november, commentary, trucial, december, hynek, raided, hydrated,
# Nearest to shows: drama, tomography, disturbances, innes, sle, enya, blackness, europa,
# Nearest to pope: sainthood, papal, skenderbeg, papacy, gregorian, pius, lockyer, mornington,
# Nearest to issue: kirby, busting, heath, burn, modernize, decisions, les, sgi,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8345 0.2994 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8174 0.2949 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8322 0.2963 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7812 0.2943 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8571 0.2954 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8522 0.2955 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8909 0.2961 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7589 0.2946 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8176 0.2954 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8255 0.2960 sec/batch
# Nearest to i: my, t, you, know, think, am, remember, go,
# Nearest to zero: two, three, one, four, five, six, eight, nine,
# Nearest to five: eight, one, six, three, four, zero, two, nine,
# Nearest to can: of, load, is, if, for, but, a, portability,
# Nearest to been: have, known, as, decades, staking, these, since, has,
# Nearest to to: in, and, as, the, a, be, of, from,
# Nearest to however: to, have, not, only, was, all, unload, attempted,
# Nearest to into: their, duct, own, eukaryotes, romanisation, thelma, the, they,
# Nearest to test: dumping, wetlands, cricket, gimpshop, bradman, ground, hazardous, unbundling,
# Nearest to experience: lisp, riveted, seconda, transits, tokelau, dosed, discipline, sees,
# Nearest to proposed: expunged, intercepts, lightfoot, robust, affirmed, refinements, inaccuracy, translating,
# Nearest to creation: lord, disbandment, tricyclic, vang, eve, inconsistent, antiarrhythmic, propounding,
# Nearest to bbc: listing, commentary, november, optic, itv, hynek, microarrays, aired,
# Nearest to shows: drama, disturbances, tomography, sle, innes, blackness, aspired, displays,
# Nearest to pope: sainthood, papal, papacy, skenderbeg, gregorian, pius, chalcedon, mornington,
# Nearest to issue: kirby, heath, decisions, busting, modernize, sgi, les, burn,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7414 0.2979 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8084 0.2952 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8321 0.2957 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8136 0.2946 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8132 0.2951 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9149 0.2958 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8206 0.2967 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8048 0.2949 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8606 0.2959 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8312 0.2952 sec/batch
# Nearest to i: t, you, my, go, am, know, think, remember,
# Nearest to zero: two, three, one, four, five, six, eight, nine,
# Nearest to five: eight, one, three, four, six, zero, two, nine,
# Nearest to can: of, load, cond, outcomes, not, portability, rely, defined,
# Nearest to been: have, known, these, decades, has, as, found, that,
# Nearest to to: in, and, of, as, be, with, the, from,
# Nearest to however: to, have, only, not, was, the, it, all,
# Nearest to into: own, duct, eukaryotes, their, romanisation, thelma, breaks, through,
# Nearest to test: dumping, wetlands, cricket, gimpshop, hazardous, ground, unbundling, bradman,
# Nearest to experience: lisp, riveted, dosed, transits, explosively, tactics, tokelau, discipline,
# Nearest to proposed: expunged, robust, intercepts, lightfoot, refinements, inaccuracy, affirmed, hou,
# Nearest to creation: lord, tricyclic, abrahamic, playable, yaoi, propounding, inconsistent, rationalist,
# Nearest to bbc: listing, itv, commentary, november, aired, raided, show, optic,
# Nearest to shows: drama, tomography, disturbances, sle, innes, displays, blackness, showing,
# Nearest to pope: sainthood, papacy, papal, skenderbeg, gregorian, pius, mornington, chalcedon,
# Nearest to issue: kirby, sgi, heath, les, busting, decisions, bestseller, injectors,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8813 0.2981 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8309 0.2941 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8100 0.2949 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8654 0.2960 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8445 0.2939 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8512 0.2951 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8393 0.2960 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8551 0.2944 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8276 0.2953 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7978 0.2956 sec/batch
# Nearest to i: t, you, my, am, know, think, remember, go,
# Nearest to zero: two, three, one, four, five, six, eight, nine,
# Nearest to five: one, eight, six, three, four, zero, two, nine,
# Nearest to can: load, for, of, portability, if, rely, not, is,
# Nearest to been: have, as, known, these, has, that, clear, decades,
# Nearest to to: in, and, of, be, as, from, this, a,
# Nearest to however: to, have, only, not, it, was, the, a,
# Nearest to into: own, the, their, duct, and, to, through, eukaryotes,
# Nearest to test: dumping, wetlands, ground, cricket, gimpshop, unbundling, bradman, observes,
# Nearest to experience: lisp, tokelau, transits, dosed, riveted, discipline, explosively, hecate,
# Nearest to proposed: expunged, affirmed, inaccuracy, intercepts, robust, lightfoot, dagobert, refinements,
# Nearest to creation: lord, damiano, disbandment, playable, svend, tricyclic, guernica, inconsistent,
# Nearest to bbc: listing, itv, commentary, aired, optic, raided, microarrays, november,
# Nearest to shows: drama, tomography, disturbances, innes, sle, show, appearances, blackness,
# Nearest to pope: sainthood, papacy, papal, gregorian, skenderbeg, mornington, pius, chalcedon,
# Nearest to issue: kirby, decisions, busting, les, heath, sgi, brokerage, disagreements,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8307 0.2989 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8479 0.2964 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8746 0.2973 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9206 0.2965 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8783 0.2941 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8440 0.2961 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7895 0.2948 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8389 0.2937 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7376 0.2945 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8697 0.2966 sec/batch
# Nearest to i: t, you, my, know, remember, am, think, go,
# Nearest to zero: two, one, three, four, five, six, eight, nine,
# Nearest to five: one, eight, six, four, three, zero, two, nine,
# Nearest to can: load, of, portability, for, not, defined, is, rely,
# Nearest to been: have, as, has, known, these, decades, clear, had,
# Nearest to to: in, as, and, with, of, a, from, be,
# Nearest to however: to, have, only, not, was, it, a, the,
# Nearest to into: duct, own, eukaryotes, thelma, to, the, their, was,
# Nearest to test: dumping, wetlands, ground, bradman, cricket, gimpshop, qualities, unbundling,
# Nearest to experience: lisp, dosed, transits, riveted, tokelau, explosively, hecate, shameless,
# Nearest to proposed: inaccuracy, expunged, affirmed, intercepts, ulm, dagobert, hou, robust,
# Nearest to creation: lord, playable, propounding, disbandment, damiano, tricyclic, svend, inconsistent,
# Nearest to bbc: listing, itv, commentary, november, optic, aired, british, trucial,
# Nearest to shows: drama, tomography, innes, disturbances, appearances, sle, show, asymmetrical,
# Nearest to pope: sainthood, papacy, skenderbeg, papal, gregorian, mornington, pius, benedict,
# Nearest to issue: kirby, decisions, les, heath, busting, ottomans, modernize, separatism,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8631 0.2983 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8563 0.2948 sec/batch

# %% [markdown]
# Restore the trained network if needed to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
